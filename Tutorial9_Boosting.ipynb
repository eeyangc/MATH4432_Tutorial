# %%
# Forward stagewise regression: Boosting for linear regression
linRegFS <- function(X, y, eps=NULL, center = T, scale = T, tol=1e-8, maxIter=1000){
  
  n  <- nrow(X)
  p  <- ncol(X)
  # ns <- length(lambda)
  
  #Check standardization consistency 
  if(!center & scale){
    warning("Centering is required when 'scale' is TRUE. 'center' is automatically set to be TRUE.")
    center <- TRUE
  }
  
  #Centering, Scaling or do nothing
  if(center){
    # beta <- matrix(0,p,ns)
    ym <- mean(y)
    y  <- y-ym
    Xm <- colMeans(X)
    X <- scale(X,center = T,scale = F)
    if(scale){
      Xsd <- sqrt(colMeans(X^2))
      X <- apply(X,MARGIN = 1,function(X,sd) X/sd,sd=Xsd)
      X <- t(X)
    }
  }

  beta <- matrix(0,p,maxIter)    # solution path for beta
  beta0 <- rep(0,maxIter)        # solution path for beta0/intercept
  betat <- rep(0,p)         # initialize beta by zero
  yhat <- rep(0,n)
  
  for(iter in 1:maxIter){
    r <- y - yhat
    g <- t(X)%*%r
    
    if(is.null(eps)) eps <- max(abs(g))/sum(r^2)
    idx <- which.max(abs(g))
    betat[idx] <- betat[idx] + eps*sign(g[idx])
    yhat <- yhat + eps*sign(g[idx])*X[,idx]
    beta[,iter] <- betat
    
    corr <- max(abs(g))/n/sd(r)
    cat(iter,"-th iteration;\t updating",idx,"-th coefficient;\t eps:",eps,";\t max corr:",corr,"\n")
    if(corr<tol){
      beta <- beta[,1:iter]
      break
    }
  }
  
  #Recover the intercept
  if(scale){
    beta0 <- ym - t(Xm/Xsd)%*%beta
    beta <- beta/Xsd
  } else if(center){
    beta0 <- ym - Xm%*%beta
  } else{
    beta0 <- ym
  }
  
  beta <- list(beta=beta,beta0=beta0,eps=eps,iteration=iter)
  attr(beta, "class") <- "linRegFS"
  return(beta)
}

# %%
library(glmnet)
rm(list=ls())
source("/Users/cmx/Desktop/PRML practice/Lasso/Lasso.R")
source("/Users/cmx/Desktop/PRML practice/linRegFS.R")
set.seed(100)
ntrain <- 100
p <- 1000
c0 <- 2
xtrain <- 2*matrix(rnorm(ntrain*p),ntrain,p) + c0
xtrain[,1] <- xtrain[,1] * 3

b <- rep(0,p)
b[1:10] <- rnorm(10)

b0 <- 1
ytrain <- xtrain%*%b + b0 + rnorm(ntrain,0,sqrt(0.5*var(xtrain%*%b)))#rnorm(ntrain,0,1)

# centerize xtrain
cc <- colMeans(xtrain)
xtrain2 <- t(t(xtrain) - cc)

# standardize xtrain?
standardizeX <- T

if(standardizeX){
  s <- sqrt(colMeans(xtrain2^2))
  xtrain2 <- t(t(xtrain2)/s)
}

# get lambda sequence
MaxLam <- max(abs(t(xtrain2)%*%ytrain))
loglam <- seq(log10(MaxLam),log10(0.2*MaxLam),length.out = 100)
lam <- 10^(loglam)

# fit using glmnet
# fitglmnet <- glmnet(xtrain,ytrain,alpha=1,lambda = lam/ntrain,standardize = T,thresh = 1e-10)
fitLasso1 <- Lasso(xtrain,ytrain,center = T,scale = T,lambda = lam,method="ACD")
fitFS <- linRegFS(xtrain,ytrain,center = T,scale = T, maxIter = 350)
# Out:
# Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-16
#  Finished!	 1  outer loops;	 0  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 2  outer loops;	 1  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 4  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 5  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 6  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 3  outer loops;	 7  inner loops
#  Finished!	 4  outer loops;	 10  inner loops
#  Finished!	 3  outer loops;	 8  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 3  outer loops;	 9  inner loops
#  Finished!	 3  outer loops;	 11  inner loops
#  Finished!	 3  outer loops;	 11  inner loops
#  Finished!	 3  outer loops;	 11  inner loops
#  Finished!	 3  outer loops;	 11  inner loops
# 1 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6690914
# 2 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6672463
# 3 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6653887
# 4 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6635183
# 5 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6616352
# 6 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6597393
# 7 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6578305
# 8 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6559087
# 9 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6539738
# 10 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6520258
# 11 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6500645
# 12 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6480899
# 13 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6461019
# 14 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6441005
# 15 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6420855
# 16 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6400569
# 17 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6380145
# 18 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6359584
# 19 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6338884
# 20 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6318045
# 21 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6297066
# 22 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6275945
# 23 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6254683
# 24 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6233277
# 25 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6211729
# 26 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6190036
# 27 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6168199
# 28 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6146215
# 29 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6124086
# 30 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6101808
# 31 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6079383
# 32 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6056809
# 33 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6034086
# 34 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.6011212
# 35 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5988187
# 36 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.596501
# 37 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.594168
# 38 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5918198
# 39 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5894561
# 40 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5870769
# 41 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5846822
# 42 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5822719
# 43 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5798459
# 44 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5774041
# 45 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5749465
# 46 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.572473
# 47 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5699835
# 48 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.567478
# 49 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5649564
# 50 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5624186
# 51 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5598646
# 52 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5572943
# 53 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5547076
# 54 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5521046
# 55 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.549485
# 56 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5468489
# 57 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5441961
# 58 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5415267
# 59 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5388406
# 60 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5361378
# 61 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5334181
# 62 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5306815
# 63 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5279279
# 64 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5251574
# 65 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5223699
# 66 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5195652
# 67 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5167435
# 68 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5139045
# 69 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5110484
# 70 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5081749
# 71 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5052842
# 72 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5023761
# 73 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5023851
# 74 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5000242
# 75 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.5000238
# 76 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4976441
# 77 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4976342
# 78 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4952355
# 79 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4952159
# 80 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4927981
# 81 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4927687
# 82 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4903315
# 83 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4902923
# 84 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4878356
# 85 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4877863
# 86 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4853099
# 87 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4852503
# 88 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4827541
# 89 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4826842
# 90 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4801679
# 91 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4800875
# 92 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.477551
# 93 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.47746
# 94 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4749032
# 95 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4748013
# 96 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4722239
# 97 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4721111
# 98 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4695131
# 99 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4693892
# 100 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4667702
# 101 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4666351
# 102 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4639951
# 103 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4638486
# 104 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4611874
# 105 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4610294
# 106 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4583468
# 107 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4581771
# 108 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.455473
# 109 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4552914
# 110 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4525656
# 111 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4523721
# 112 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4496245
# 113 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4494189
# 114 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4466492
# 115 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4464313
# 116 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4436396
# 117 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.4434093
# 118 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.
-th iteration;	 updating 767 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2622864
# 278 -th iteration;	 updating 132 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2627857
# 279 -th iteration;	 updating 754 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2612042
# 280 -th iteration;	 updating 534 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2618462
# 281 -th iteration;	 updating 6 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2596964
# 282 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2595409
# 283 -th iteration;	 updating 734 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.259702
# 284 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2596219
# 285 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2590086
# 286 -th iteration;	 updating 10 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2592103
# 287 -th iteration;	 updating 501 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2588781
# 288 -th iteration;	 updating 132 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2590758
# 289 -th iteration;	 updating 767 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2585223
# 290 -th iteration;	 updating 903 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2578605
# 291 -th iteration;	 updating 734 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2568888
# 292 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2565545
# 293 -th iteration;	 updating 534 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.256861
# 294 -th iteration;	 updating 754 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2554343
# 295 -th iteration;	 updating 929 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2552189
# 296 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2553136
# 297 -th iteration;	 updating 501 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2544195
# 298 -th iteration;	 updating 132 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2555981
# 299 -th iteration;	 updating 767 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2542177
# 300 -th iteration;	 updating 10 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2533306
# 301 -th iteration;	 updating 734 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2535078
# 302 -th iteration;	 updating 903 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2536558
# 303 -th iteration;	 updating 971 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2537846
# 304 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2527853
# 305 -th iteration;	 updating 534 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2529708
# 306 -th iteration;	 updating 6 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2514182
# 307 -th iteration;	 updating 3 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2507576
# 308 -th iteration;	 updating 501 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2502295
# 309 -th iteration;	 updating 132 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2508736
# 310 -th iteration;	 updating 373 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2507761
# 311 -th iteration;	 updating 10 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2499576
# 312 -th iteration;	 updating 710 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2499714
# 313 -th iteration;	 updating 734 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2498428
# 314 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2507735
# 315 -th iteration;	 updating 754 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2489669
# 316 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2491972
# 317 -th iteration;	 updating 903 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2494258
# 318 -th iteration;	 updating 767 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.248887
# 319 -th iteration;	 updating 386 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2487568
# 320 -th iteration;	 updating 971 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2482864
# 321 -th iteration;	 updating 534 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2481312
# 322 -th iteration;	 updating 501 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2476079
# 323 -th iteration;	 updating 676 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2472575
# 324 -th iteration;	 updating 734 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2470757
# 325 -th iteration;	 updating 655 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2478903
# 326 -th iteration;	 updating 710 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2472448
# 327 -th iteration;	 updating 549 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.246512
# 328 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2467399
# 329 -th iteration;	 updating 74 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2465275
# 330 -th iteration;	 updating 950 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2463908
# 331 -th iteration;	 updating 132 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2466908
# 332 -th iteration;	 updating 903 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2466329
# 333 -th iteration;	 updating 548 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2453013
# 334 -th iteration;	 updating 373 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2454443
# 335 -th iteration;	 updating 676 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.244888
# 336 -th iteration;	 updating 386 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2447531
# 337 -th iteration;	 updating 501 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2455337
# 338 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2451611
# 339 -th iteration;	 updating 734 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2449674
# 340 -th iteration;	 updating 1 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.244305
# 341 -th iteration;	 updating 534 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2440874
# 342 -th iteration;	 updating 754 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2448895
# 343 -th iteration;	 updating 767 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2436148
# 344 -th iteration;	 updating 132 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2440913
# 345 -th iteration;	 updating 950 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2425163
# 346 -th iteration;	 updating 710 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2425166
# 347 -th iteration;	 updating 10 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2421598
# 348 -th iteration;	 updating 903 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2423682
# 349 -th iteration;	 updating 622 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2417312
# 350 -th iteration;	 updating 676 -th coefficient;	 eps: 0.04763023 ;	 max corr: 0.2425666

# %%
library(repr)
options(repr.plot.width=8, repr.plot.height=4)
par(mfrow=c(1,2))
matplot(colSums(abs(fitLasso1$beta)),t(fitLasso1$beta),type="l",xlab=expression("||"*beta*"||"[1]),ylab=expression(beta),main="my CD with active set")
matplot(colSums(abs(fitFS$beta)),t(fitFS$beta),type="l",xlab=expression("||"*beta*"||"[1]),ylab=expression(beta),main="Boosting Forward Stagewise")
# Out:
# Plot with title “Boosting Forward Stagewise”
